# %%
import pandas as pd
import numpy as np
from clustergrammer import Network
net = Network()
# Out:
# no persistent_cat

# %%
net.load_file('txt/ds_plasma.txt')
# Out:
# yes persistent_cat
# True
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-f1893ceede69> in <module>()
# ----> 1 net.load_file('txt/ds_plasma.txt')
#
# /Users/nickfernandez/Documents/clustergrammer-py/clustergrammer/__init__.pyc in load_file(self, filename)
#      44     Load TSV file.
#      45     '''
# ---> 46     load_data.load_file(self, filename)
#      47
#      48   def load_stdin(self):
#
# /Users/nickfernandez/Documents/clustergrammer-py/clustergrammer/load_data.pyc in load_file(net, filename)
#      31     filename = filename.split('/')[-1]
#      32
# ---> 33   net.load_tsv_to_net(buff, filename)
#      34
#      35 def load_stdin(net):
#
# /Users/nickfernandez/Documents/clustergrammer-py/clustergrammer/__init__.pyc in load_tsv_to_net(self, file_buffer, filename)
#      57     be possible to load data without having to read from a file.
#      58     '''
# ---> 59     load_data.load_tsv_to_net(self, file_buffer, filename)
#      60
#      61   def load_vect_post_to_net(self, vect_post):
#
# /Users/nickfernandez/Documents/clustergrammer-py/clustergrammer/load_data.pyc in load_tsv_to_net(net, file_buffer, filename)
#      60   tmp_df = proc_df_labels.main(tmp_df)
#      61
# ---> 62   net.df_to_dat(tmp_df, True)
#      63   net.dat['filename'] = filename
#      64
#
# /Users/nickfernandez/Documents/clustergrammer-py/clustergrammer/__init__.pyc in df_to_dat(self, df, define_cat_colors)
#     132     Load Pandas DataFrame (will be deprecated).
#     133     '''
# --> 134     data_formats.df_to_dat(self, df, define_cat_colors)
#     135
#     136   def set_cat_color(self, axis, cat_index, cat_name, inst_color):
#
# /Users/nickfernandez/Documents/clustergrammer-py/clustergrammer/data_formats.pyc in df_to_dat(net, df, define_cat_colors)
#      32     net.dat['mat_orig'] = df['mat_orig'].values
#      33
# ---> 34   categories.dict_cat(net, define_cat_colors=define_cat_colors)
#      35
#      36 def dat_to_df(net):
#
# /Users/nickfernandez/Documents/clustergrammer-py/clustergrammer/categories.pyc in dict_cat(net, define_cat_colors)
#      82       for cat_index in all_cats:
#      83
# ---> 84         cat_colors[inst_rc][cat_index] = {}
#      85
#      86         cat_names = sorted(list(set(net.dat['node_info'][inst_rc][cat_index])))
#
# TypeError: 'bool' object has no attribute '__getitem__'

# %%
hasattr(net, 'cat')
# Out:
# False

# %%
df_plasma = net.export_df()

# %%
net.viz['cat_colors']
# Out:
# {'col': {'cat-0': {'Marker-type: phospho marker': '#17becf',
#    'Marker-type: surface marker': '#6b6ecf'}},
#  'row': {'cat-0': {'Majority-Treatment: Plasma': '#dbdb8d'}, 'cat-1': {}}}

# %%
net.load_file('txt/ds_pma.txt')
# Out:
# {'col': {}, 'row': {}}

# %%
df_pma = net.export_df()

# %%
net.viz['cat_colors']
# Out:
# {'col': {'cat-0': {'Marker-type: phospho marker': '#8c564b',
#    'Marker-type: surface marker': '#5254a3'}},
#  'row': {'cat-0': {'Majority-Treatment: PMA': '#c5b0d5'}, 'cat-1': {}}}

# %%
# generate random matrix
num_rows = 500
num_cols = 10
np.random.seed(seed=100)
mat = np.random.rand(num_rows, num_cols)

# make row and col labels
rows = range(num_rows)
cols = range(num_cols)
rows = [str(i) for i in rows]
cols = [str(i) for i in cols]

# make dataframe 
df = pd.DataFrame(data=mat, columns=cols, index=rows)

# %%
net.viz['cat_colors']
# Out:
# {'col': {'cat-0': {'Marker-type: phospho marker': '#17becf',
#    'Marker-type: surface marker': '#6b6ecf'}},
#  'row': {'cat-0': {'Majority-Treatment: Plasma': '#dbdb8d'}, 'cat-1': {}}}

# %%
net.load_df(df)

# %%
net.viz['cat_colors']
# Out:
# {'col': {}, 'row': {}}

# %%
net.set_cat_color('col', 1, 'Category: one', 'blue')

# %%
net.viz['cat_colors']
# Out:
# {'col': {'cat-0': {'Marker-type: phospho marker': '#17becf',
#    'Marker-type: surface marker': '#6b6ecf'}},
#  'row': {'cat-0': {'Majority-Treatment: Plasma': '#dbdb8d'}, 'cat-1': {}}}

# %%
df = net.export_df()

# %%
net.load_df(df)
df = df.transpose()
# Out:
# 10
# False
# 100
# False
# 101
# False
# 102
# False
# 103
# False
# 104
# False
# 105
# False
# 106
# False
# 107
# False
# 108
# False
# 109
# False
# 11
# False
# 110
# False
# 111
# False
# 112
# False
# 113
# False
# 114
# False
# 115
# False
# 116
# False
# 117
# False
# 118
# False
# 119
# False
# 12
# False
# 120
# False
# 121
# False
# 122
# False
# 123
# False
# 125
# False
# 126
# False
# 127
# False
# 128
# False
# 129
# False
# 13
# False
# 130
# False
# 131
# False
# 132
# False
# 133
# False
# 134
# False
# 135
# False
# 136
# False
# 137
# False
# 138
# False
# 139
# False
# 14
# False
# 140
# False
# 141
# False
# 142
# False
# 143
# False
# 144
# False
# 145
# False
# 146
# False
# 147
# False
# 148
# False
# 149
# False
# 15
# False
# 150
# False
# 151
# False
# 152
# False
# 153
# False
# 154
# False
# 155
# False
# 156
# False
# 157
# False
# 158
# False
# 159
# False
# 16
# False
# 160
# False
# 161
# False
# 162
# False
# 163
# False
# 164
# False
# 165
# False
# 166
# False
# 167
# False
# 168
# False
# 169
# False
# 17
# False
# 170
# False
# 171
# False
# 172
# False
# 173
# False
# 174
# False
# 175
# False
# 176
# False
# 177
# False
# 178
# False
# 179
# False
# 18
# False
# 180
# False
# 181
# False
# 182
# False
# 183
# False
# 184
# False
# 185
# False
# 186
# False
# 187
# False
# 188
# False
# 189
# False
# 19
# False
# 190
# False
# 191
# False
# 192
# False
# 193
# False
# 194
# False
# 195
# False
# 196
# False
# 197
# False
# 198
# False
# 199
# False
# 2
# False
# 20
# False
# 200
# False
# 201
# False
# 202
# False
# 203
# False
# 204
# False
# 205
# False
# 206
# False
# 207
# False
# 208
# False
# 209
# False
# 21
# False
# 210
# False
# 211
# False
# 212
# False
# 213
# False
# 214
# False
# 215
# False
# 216
# False
# 218
# False
# 219
# False
# 22
# False
# 220
# False
# 221
# False
# 223
# False
# 226
# False
# 227
# False
# 228
# False
# 229
# False
# 23
