# %%
from clustergrammer import Network
net = Network()

# %%
net.load_file('txt/rc_two_cats.txt')

# %%
net.make_clust(sim_mat=True)
# Out:
# True
# initialize which_sim
# make similarity matrices of rows and columns, add to viz data structure
# in make_sim_mat, which_sim: ['row', 'col']

# %%
net.sim.keys()
# Out:
# ['col', 'row']

# %%
net.widget('sim_row')
# Out:
# '{"mat": [[1.0, -0.13819231887331052, 0.0, 0.12857082062069292, 0.5715262466094556, 0.2195385826785362, 0.6185889634564334, 0.0, -0.13223539131636697, -0.10615422126181273, 0.0, -0.24665483464934557, 0.0, 0.5325571979004502, 0.0, 0.2109573683839907, 0.19453144992151072, 0.0, 0.23851675064268252, 0.0, 0.13063540149879949, 0.0, 0.12825378949083033, 0.12865205193954443, -0.32539739035329696, -0.279412360419784, 0.30924715003187986, 0.0, -0.1919181212285952, 0.2759653909871469, 0.16610633977722, 0.0, -0.19783447986304203, -0.25077695875327954, -0.20685490708637455, 0.0, 0.0, 0.0], [-0.13819231887331052, 1.0, 0.0, 0.0, 0.14017673035419786, 0.0, 0.0, 0.0, -0.18934423315479698, 0.0, 0.0, -0.5772684905372967, -0.20855491195977893, -0.16897766619078824, 0.117172175015269, 0.10049539902670812, 0.0, 0.2775155091020425, -0.12974903912685587, -0.23396757442567306, 0.0, -0.16333173281072333, 0.6815350266695095, 0.0, 0.21921433894323616, -0.20430677329931735, 0.0, 0.0, 0.20473159734915136, 0.0, 0.0
# ...

# %%
net.sim['col'].keys()
# Out:
# ['mat', 'links', 'views', 'cat_colors', 'row_nodes', 'col_nodes']

# %%
from clustergrammer_widget import clustergrammer_widget

# %%
clustergrammer_widget(network=net.widget('sim_col'))
